#      -----------------------------        788.5/953.9 kB 146.1 kB/s eta 0:00:02
#      -------------------------------      829.4/953.9 kB 153.8 kB/s eta 0:00:01
#      --------------------------------     849.9/953.9 kB 155.3 kB/s eta 0:00:01
#      --------------------------------     860.2/953.9 kB 156.8 kB/s eta 0:00:01
#      --------------------------------     860.2/953.9 kB 156.8 kB/s eta 0:00:01
#      --------------------------------     860.2/953.9 kB 156.8 kB/s eta 0:00:01
#      --------------------------------     860.2/953.9 kB 156.8 kB/s eta 0:00:01
#      ------------------------------------ 953.9/953.9 kB 167.3 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in c:\users\admin\appdata\roaming\python\python311\site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\admin\appdata\roaming\python\python311\site-packages (from gymnasium) (4.13.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading farama_notifications-0.0.6-py3-none-any.whl (2.9 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.6 gymnasium-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym
import numpy as np

# %%
# Create FrozenLake environment
env = gym.make("FrozenLake-v1", map_name="4x4", is_slippery=True)

# %%
# Access the unwrapped environment to use the transition model
env = env.unwrapped

# %%
# Number of states and actions
n_states = env.observation_space.n
n_actions = env.action_space.n

# %%
# Parameters
gamma = 0.91
theta = 1e-8

# %%
# Random policy: each action has equal probability
policy = np.ones((n_states, n_actions)) / n_actions

# %%
# Initialize value function
V = np.zeros(n_states)

# -------------------------------------------------
# Policy Evaluation Function
# -------------------------------------------------

def policy_evaluation(env, policy, gamma, theta):
    """
    Performs iterative policy evaluation using the Bellman expectation equation.

    Parameters:
        env    : Gymnasium FrozenLake environment
        policy : Fixed policy to be evaluated
        gamma  : Discount factor
        theta  : Convergence threshold

    Returns:
        V         : Estimated state-value function
        iteration : Number of iterations used for convergence
    """
    
    iteration = 0
    
    while True:
        delta = 0

        for s in range(n_states):
            v = V[s]
            new_v = 0

            # Loop through all possible actions
            for a, action_prob in enumerate(policy[s]):

                # Transition model: (probability, next_state, reward, done)
                for prob, next_state, reward, done in env.P[s][a]:
                    new_v += action_prob * prob * (
                        reward + gamma * V[next_state]
                    )

            V[s] = new_v
            delta = max(delta, abs(v - V[s]))

        iteration += 1

        if delta < theta:
            break



    return V, iteration

# %%
# Run policy evaluation
V, iterations = policy_evaluation(env, policy, gamma, theta)

print("Name: Gnanendran N")
print("Register Number: 212223240037")
print("Number of iterations:", iterations)
print("\nState-Value Function:")
print(V)

print("Name: Gnanendran N")
print("Register Number: 212223240037")
print("\nState-Value Function as 4x4 Grid:")
print(np.round(V.reshape(4, 4), 4))

env.close()
# Out:
# Name: Gnanendran N
# Register Number: 212223240037
# Number of iterations: 39
#
# State-Value Function:
# [0.00498902 0.00464252 0.01077513 0.00449787 0.00730924 0.
#  0.0274477  0.         0.01983028 0.06002654 0.10987411 0.
#  0.         0.13414855 0.39548888 0.        ]
# Name: Gnanendran N
# Register Number: 212223240037
#
# State-Value Function as 4x4 Grid:
# [[0.005  0.0046 0.0108 0.0045]
#  [0.0073 0.     0.0274 0.    ]
#  [0.0198 0.06   0.1099 0.    ]
#  [0.     0.1341 0.3955 0.    ]]
